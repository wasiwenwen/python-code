# %%
#第四次作業
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rc('font', family = 'Noto Sans CJK TC')

# %%
df = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=33307&md5_url=73642bf29ddcf1e9ce30b6d7fb2320e7')

# %%
df2 = df[df['location'] != '新北市']

# %%
# gp=df2.groupby(by=['type','location'])
# newdf=gp.size()
# newdf.reset_index(name='times')
# Out:
#      type location  times
# 0    住宅竊盜   新北市三峽區      6
# 1    住宅竊盜   新北市三芝區      2
# 2    住宅竊盜   新北市三重區    134
# 3    住宅竊盜   新北市中和區    128
# 4    住宅竊盜   新北市五股區     15
# 5    住宅竊盜   新北市八里區      8
# 6    住宅竊盜   新北市土城區     92
# 7    住宅竊盜   新北市平溪區      1
# 8    住宅竊盜   新北市新店區     75
# 9    住宅竊盜   新北市新莊區     92
# 10   住宅竊盜   新北市板橋區    192
# 11   住宅竊盜   新北市林口區      6
# 12   住宅竊盜   新北市樹林區     50
# 13   住宅竊盜   新北市永和區     69
# 14   住宅竊盜   新北市汐止區     37
# 15   住宅竊盜   新北市泰山區     23
# 16   住宅竊盜   新北市淡水區      7
# 17   住宅竊盜   新北市深坑區     12
# 18   住宅竊盜   新北市烏來區      2
# 19   住宅竊盜   新北市瑞芳區     21
# 20   住宅竊盜   新北市石碇區      2
# 21   住宅竊盜   新北市石門區      3
# 22   住宅竊盜   新北市萬里區      7
# 23   住宅竊盜   新北市蘆洲區     32
# 24   住宅竊盜   新北市貢寮區      2
# 25   住宅竊盜   新北市金山區      9
# 26   住宅竊盜   新北市雙溪區      1
# 27   住宅竊盜   新北市鶯歌區      9
# 28   機車竊盜   新北市三峽區     88
# 29   機車竊盜   新北市三芝區      7
# ..    ...      ...    ...
# 68   汽車竊盜   新北市淡水區     26
# 69   汽車竊盜   新北市深坑區      2
# 70   汽車竊盜   新北市瑞芳區      2
# ...

# %%
var = newdf.groupby(['location','type']).sum()

# %%
result = var.unstack()
where_are_nan = np.isnan(result)
result[where_are_nan] = 0
result['sum'] = result['住宅竊盜'] + result['機車竊盜'] + result['汽車竊盜'] + result['自行車竊盜']

# %%
result
# Out:
# type       住宅竊盜   機車竊盜  汽車竊盜  自行車竊盜    sum
# location
# 新北市三峽區      6.0   88.0  26.0   15.0  135.0
# 新北市三芝區      2.0    7.0   5.0    0.0   14.0
# 新北市三重區    134.0  270.0  64.0   57.0  525.0
# 新北市中和區    128.0  206.0  31.0   33.0  398.0
# 新北市五股區     15.0   39.0  30.0    4.0   88.0
# 新北市八里區      8.0   14.0  39.0    2.0   63.0
# 新北市土城區     92.0   72.0  32.0   63.0  259.0
# 新北市平溪區      1.0    1.0   0.0    1.0    3.0
# 新北市新店區     75.0   56.0  25.0   13.0  169.0
# 新北市新莊區     92.0  173.0  45.0   49.0  359.0
# 新北市板橋區    192.0  227.0  37.0   99.0  555.0
# 新北市林口區      6.0   26.0  49.0   20.0  101.0
# 新北市樹林區     50.0   85.0  41.0   22.0  198.0
# 新北市永和區     69.0   71.0  10.0   19.0  169.0
# 新北市汐止區     37.0   84.0  42.0   10.0  173.0
# 新北市泰山區     23.0   30.0  18.0   10.0   81.0
# 新北市淡水區      7.0   86.0  26.0    5.0  124.0
# 新北市深坑區     12.0    3.0   2.0    0.0   17.0
# 新北市烏來區      2.0    0.0   0.0    0.0    2.0
# 新北市瑞芳區     21.0    7.0   2.0    1.0   31.0
# ...

# %%
r = result.sort_values(by = 'sum', ascending=False)
r
r.plot(y = r.type, kind='bar',stacked=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-8fcf21faf820> in <module>()
#       1 r = result.sort_values(by = 'sum', ascending=False)
#       2 r
# ----> 3 r.plot(y = r.type,kind='bar',stacked=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'type'
