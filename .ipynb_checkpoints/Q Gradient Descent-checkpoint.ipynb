# %% [markdown]
# # 利用Gradient Descent找出函數的最小值

# %% [markdown]
# ## 讀進基本套件

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random as rd

# %% [markdown]
# ## 決定Loss function

# %% [markdown]
# #### $f(x) = (x - 9)(x - 4)(x + 8)(x + 7)$

# %%
def LossFunction(x):
    return  (x - 9) * (x - 4) * (x + 8) * (x + 7)

x = np.linspace(-10, 10, 100)
y = LossFunction(x)

plt.plot(x, y)

# %% [markdown]
# ## 對Loss function做微分
# #### $f'(x) = 4x^3 + 6x^2 -206x - 188$

# %%
def dLossfunction(x):
    return 4 * x ** 3 + 6  * x ** 2 - 206 * x - 188

# %% [markdown]
# ## Gradient Descent

# %%
def GradientDescent(w, LearningRate):
    w -= dLossfunction(w) * LearningRate
    return w

# %% [markdown]
# ### 基本嘗試

# %%
start = 0 #從零開始
LR = 0.0005 #learning rate，先隨便選一個數字
N = 100 #最多做一百次

wlist = [start]
ylist = [LossFunction(start)] 
clist = [0] #根據次數改變顏色，從紫到黃

point = start
for i in range(0, N):
    point = round(GradientDescent(point, LR), 4) #取到小數點下四位
    if point in wlist: break #重複了就停止
    wlist.append(point)
    ylist.append(LossFunction(point))
    clist.append(i // 5)
    
plt.plot(x, y)
plt.scatter(wlist, ylist, c = clist)
plt.scatter(wlist[-1], ylist[-1], c = 'r') #標出最後的點，為紅色
print('最後走到的區域最小值為%.4f，此時w為%.4f' %(ylist[-1], wlist[-1]))
print('過程中有找到的區域最小值為%.4f' %min(ylist))
print('次數為', len(wlist) - 1)
# Out:
# 最後走到的區域最小值為-1261.4047，此時w為6.9214
# 過程中有找到的區域最小值為-1261.4047
# 次數為 60

# %% [markdown]
# ### 好奇1：若是稍微改變一下Learning rate呢？
# #### 稍微設大一點→可能會不停錯過最低點，亂跳，沒有好好收斂，最後不是停在最低點

# %%
LR = 0.006 #learning rate
N = 100 #最多做一百次

wlist1 = [start]
ylist1 = [LossFunction(start)] 
clist1 = [0] #根據次數改變顏色，從紫到黃

point = start
for i in range(0, N):
    point = round(GradientDescent(point, LR), 4) #取到小數點下四位
    if point in wlist1: break #重複了就停止
    wlist1.append(point)
    ylist1.append(LossFunction(point))
    clist1.append(i // 5)

plt.plot(x, y)
plt.scatter(wlist1, ylist1, c = clist1)
plt.scatter(wlist1[-1], ylist1[-1], c = 'r') #標出最後的點，為紅色
print('最後走到的區域最小值為%.4f，此時w為%.4f' %(ylist1[-1], wlist1[-1]))
print('過程中有找到的區域最小值為%.4f' %min(ylist1))
print('次數為', len(wlist1) - 1)
# Out:
# 最後走到的區域最小值為529.1570，此時w為3.2014
# 過程中有找到的區域最小值為-1259.7949
# 次數為 100

# %% [markdown]
# #### 稍微設小一點→可能會移動緩慢花了100次還到不了最低點

# %%
LR = 0.0001 #learning rate
N = 100 #最多做一百次

wlist2 = [start]
ylist2 = [LossFunction(start)] 
clist2 = [0] #根據次數改變顏色，從紫到黃

point = start
for i in range(0, N):
    point = round(GradientDescent(point, LR), 4) #取到小數點下四位
    if point in wlist2: break #重複了就停止
    wlist2.append(point)
    ylist2.append(LossFunction(point))
    clist2.append(i // 5)
    
plt.plot(x, y)
plt.scatter(wlist2, ylist2, c = clist2)
plt.scatter(wlist2[-1], ylist2[-1], c = 'r') #標出最後的點，為紅色
print('最後走到的區域最小值為%.4f，此時w為%.4f' %(ylist2[-1], wlist2[-1]))
print('過程中有找到的區域最小值為%.4f' %min(ylist2))
print('次數為', len(wlist2) - 1)
# Out:
# 最後走到的區域最小值為-402.4838，此時w為4.6269
# 過程中有找到的區域最小值為-402.4838
# 次數為 100

# %% [markdown]
# #### 結論與發現1：設定適當的learning rate，可以讓人事半功倍，一步步走向區域最小值，太大或太小都有可能錯過最小值

# %% [markdown]
# ### 好奇2：那如果起始值剛好就很接近最小值呢？Learning rate還有影響嗎？
# #### 中learning rate→依然表現良好

# %%
LR = 0.0005 #learning rate，先隨便選一個數字
N = 100 #最多做一百次

start1 = 7 #更改起始點
wlist3 = [start1]
ylist3 = [LossFunction(start1)] 
clist3 = [0] #根據次數改變顏色，從紫到黃

point = start1
for i in range(0, N):
    point = round(GradientDescent(point, LR), 4) #取到小數點下四位
    if point in wlist3: break #重複了就停止
    wlist3.append(point)
    ylist3.append(LossFunction(point))
    clist3.append(i // 5)
    
plt.plot(x, y)
plt.scatter(wlist3, ylist3, c = clist3)
plt.scatter(wlist3[-1], ylist3[-1], c = 'r') #標出最後的點，為紅色
print('最後走到的區域最小值為%.4f，此時w為%.4f' %(ylist3[-1], wlist3[-1]))
print('過程中有找到的區域最小值為%.4f' %min(ylist3))
print('次數為', len(wlist3) - 1)
# Out:
# 最後走到的區域最小值為-1261.4047，此時w為6.9217
# 過程中有找到的區域最小值為-1261.4047
# 次數為 24

# %% [markdown]
# #### 大Learning rate→依然花費一堆力氣亂跳

# %%
LR = 0.006 #learning rate
N = 100 #最多做一百次

wlist4 = [start1]
ylist4 = [LossFunction(start1)] 
clist4 = [0] #根據次數改變顏色，從紫到黃

point = start1
for i in range(0, N):
    point = round(GradientDescent(point, LR), 4) #取到小數點下四位
    if point in wlist4: break #重複了就停止
    wlist4.append(point)
    ylist4.append(LossFunction(point))
    clist4.append(i // 5)

plt.plot(x, y)
plt.scatter(wlist4, ylist4, c = clist4)
plt.scatter(wlist4[-1], ylist4[-1], c = 'r') #標出最後的點，為紅色
print('最後走到的區域最小值為%.4f，此時w為%.4f' %(ylist4[-1], wlist4[-1]))
print('過程中有找到的區域最小值為%.4f' %min(ylist4))
print('次數為', len(wlist4) - 1)
# Out:
# 最後走到的區域最小值為-918.9011，此時w為8.0665
# 過程中有找到的區域最小值為-1260.0000
# 次數為 100

# %% [markdown]
# #### 小Learning rate→表現不錯， 但比中Learning rate花費更多的次數找到最小值

# %%
LR = 0.0001 #learning rate
N = 100 #最多做一百次

wlist5 = [start1]
ylist5 = [LossFunction(start1)] 
clist5 = [0] #根據次數改變顏色，從紫到黃

point = start1
for i in range(0, N):
    point = round(GradientDescent(point, LR), 4) #取到小數點下四位
    if point in wlist5: break #重複了就停止
    wlist5.append(point)
    ylist5.append(LossFunction(point))
    clist5.append(i // 5)
    
plt.plot(x, y)
plt.scatter(wlist5, ylist5, c = clist5)
plt.scatter(wlist5[-1], ylist5[-1], c = 'r') #標出最後的點，為紅色
print('最後走到的區域最小值為%.4f，此時w為%.4f' %(ylist5[-1], wlist5[-1]))
print('過程中有找到的區域最小值為%.4f' %min(ylist5))
print('次數為', len(wlist5) - 1)
# Out:
# 最後走到的區域最小值為-1261.4044，此時w為6.9226
# 過程中有找到的區域最小值為-1261.4044
# 次數為 90

# %% [markdown]
# #### 結論與發現2：設定適當的learning rate，可以讓人事半功倍，一步步走向區域最小值，太大或太小都有可能花費不必要的力氣
