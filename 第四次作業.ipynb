# 96  自行車竊盜   新北市金山區      1
# 97  自行車竊盜   新北市鶯歌區     12
#
# [98 rows x 3 columns]

# %%
newdf[:20].plot.bar(x='location', y=['times'])

# %%
var = df.groupby(['BMI','Gender']).Sales.sum()
result = var.unstack()
result

# %%
place = np.array(set(df2.location.values))

# %%
crime = np.array(set(df2.type.values))

# %%
df3 = df2[df2['type'] == '住宅竊盜']
df4 = df3['location'].value_counts()
N = len(df4)
ind = np.arange(N)    # the x locations for the groups

# %%
df10 =  df2[df2['type'] == '汽車竊盜']
df11 =  df10['location'].value_counts().plot.bar()

# %%
df20 = df2[df2['type'] == '自行車竊盜']
df21 = df20['location'].value_counts().plot.bar()

# %%
df30 =  df2[df2['type'] == '機車竊盜']
df31 =  df30['location'].value_counts()

# %%
plt.bar(df4[0], df4[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2dfcf00621d2> in <module>
# ----> 1 plt.bar(df4[0], df4[1])
#
# TypeError: 'AxesSubplot' object does not support indexing

# %%
p1 = plt.bar(ind, df4)
plt.xticks(ind, df4.index)
# Out:
# ([<matplotlib.axis.XTick at 0x1ceafcbe0b8>,
#   <matplotlib.axis.XTick at 0x1ceafcb29e8>,
#   <matplotlib.axis.XTick at 0x1ceafcb2ac8>,
#   <matplotlib.axis.XTick at 0x1ceafd10cc0>,
#   <matplotlib.axis.XTick at 0x1ceafd1a198>,
#   <matplotlib.axis.XTick at 0x1ceafd1a668>,
#   <matplotlib.axis.XTick at 0x1ceafd1ab38>,
#   <matplotlib.axis.XTick at 0x1ceafd220b8>,
#   <matplotlib.axis.XTick at 0x1ceafd22518>,
#   <matplotlib.axis.XTick at 0x1ceafd229e8>,
#   <matplotlib.axis.XTick at 0x1ceafd22eb8>,
#   <matplotlib.axis.XTick at 0x1ceafd2a400>,
#   <matplotlib.axis.XTick at 0x1ceafd22f98>,
#   <matplotlib.axis.XTick at 0x1ceafd1a710>,
#   <matplotlib.axis.XTick at 0x1ceafd2a898>,
#   <matplotlib.axis.XTick at 0x1ceafd2ac50>,
#   <matplotlib.axis.XTick at 0x1ceafd32198>,
#   <matplotlib.axis.XTick at 0x1ceafd326a0>,
#   <matplotlib.axis.XTick at 0x1ceafd32ba8>,
#   <matplotlib.axis.XTick at 0x1ceafd39160>,
#   <matplotlib.axis.XTick at 0x1ceafd395f8>,
#   <matplotlib.axis.XTick at 0x1ceafd32780>,
#   <matplotlib.axis.XTick at 0x1ceafd2aa58>,
#   <matplotlib.axis.XTick at 0x1ceafd397b8>,
#   <matplotlib.axis.XTick at 0x1ceafd39f28>,
#   <matplotlib.axis.XTick at 0x1ceafd42470>,
#   <matplotlib.axis.XTick at 0x1ceafd42978>,
#   <matplotlib.axis.XTick at 0x1ceafd42e80>],
#  <a list of 28 Text xticklabel objects>)
