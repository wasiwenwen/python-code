# %%
#第四次作業
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rc('font', family = 'Noto Sans CJK TC')

# %%
df = pd.read_csv('https://quality.data.gov.tw/dq_download_csv.php?nid=33307&md5_url=73642bf29ddcf1e9ce30b6d7fb2320e7')

# %%
df2 = df[df['location'] != '新北市'].copy()
df2.drop(['date'], axis=1, inplace=True)

# %%
df2
# Out:
#        type location
# 0      住宅竊盜   新北市三重區
# 1      住宅竊盜   新北市中和區
# 2      住宅竊盜   新北市樹林區
# 3      汽車竊盜   新北市中和區
# 13     機車竊盜   新北市中和區
# 14     機車竊盜   新北市汐止區
# 15     機車竊盜   新北市淡水區
# 16     機車竊盜   新北市樹林區
# 17     住宅竊盜   新北市中和區
# 18     住宅竊盜   新北市永和區
# 19     住宅竊盜   新北市新店區
# 20     住宅竊盜   新北市瑞芳區
# 23     機車竊盜   新北市中和區
# 24     機車竊盜   新北市汐止區
# 25     機車竊盜   新北市板橋區
# 26     機車竊盜   新北市新店區
# 27     住宅竊盜   新北市三重區
# 28     汽車竊盜   新北市三重區
# 31     機車竊盜   新北市永和區
# 32     住宅竊盜   新北市中和區
# 33     住宅竊盜   新北市永和區
# 34     住宅竊盜   新北市深坑區
# 35     住宅竊盜   新北市新莊區
# 37     機車竊盜   新北市三峽區
# 38     機車竊盜   新北市中和區
# 39     機車竊盜   新北市泰山區
# 40     住宅竊盜   新北市土城區
# 41     住宅竊盜   新北市板橋區
# 42     住宅竊盜   新北市新莊區
# 43     住宅竊盜   新北市蘆洲區
# ...     ...      ...
# 6082  自行車竊盜   新北市板橋區
# 6083  自行車竊盜   新北市新莊區
# 6088   住宅竊盜   新北市樹林區
# 6089   機車竊盜   新北市三重區
# 6090  自行車竊盜   新北市蘆洲區
# 6091   住宅竊盜   新北市中和區
# 6094   機車竊盜   新北市新莊區
# 6095   機車竊盜   新北市蘆洲區
# 6096  自行車竊盜   新北市板橋區
# 6100   機車竊盜   新北市五股區
# 6101   機車竊盜   新北市樹林區
# 6102   機車竊盜   新北市樹林區
# 6103   機車竊盜   新北市蘆洲區
# 6111  自行車竊盜   新北市板橋區
# 6112  自行車竊盜   新北市新莊區
# 6114   機車竊盜   新北市汐止區
# 6116   機車竊盜   新北市蘆洲區
# 6117  自行車竊盜   新北市中和區
# 6118   住宅竊盜   新北市中和區
# 6121   機車竊盜   新北市中和區
# 6122   機車竊盜   新北市五股區
# 6123  自行車竊盜   新北市土城區
# 6124  自行車竊盜   新北市土城區
# 6125  自行車竊盜   新北市三重區
# 6126   住宅竊盜   新北市三重區
# 6130   機車竊盜   新北市鶯歌區
# 6131  自行車竊盜   新北市蘆洲區
# 6132   住宅竊盜   新北市樹林區
# 6136   機車竊盜   新北市中和區
# 6139   機車竊盜   新北市三峽區
#
# [3835 rows x 2 columns]

# %%
newdf[:20].plot.bar(x='location', y=['times'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3c1e1130e7d9> in <module>
# ----> 1 newdf[:20].plot.bar(x='location', y=['times'])
#
# NameError: name 'newdf' is not defined

# %%
var = df.groupby(['BMI','Gender']).Sales.sum()
result = var.unstack()
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-907b7c482e6d> in <module>
# ----> 1 var = df.groupby(['BMI','Gender']).Sales.sum()
#       2 result = var.unstack()
#       3 result
#
# c:\users\ts105\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# c:\users\ts105\appdata\local\programs\python\python37\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# c:\users\ts105\appdata\local\programs\python\python37\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# c:\users\ts105\appdata\local\programs\python\python37\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     576                 in_axis, name, level, gpr = False, None, gpr, None
#     577             else:
# --> 578                 raise KeyError(gpr)
#     579         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     580             # Add key to exclusions
#
# KeyError: 'BMI'

# %%
place = np.array(set(df2.location.values))

# %%
crime = np.array(set(df2.type.values))

# %%
df3 = df2[df2['type'] == '住宅竊盜']
df4 = df3['location'].value_counts()
N = len(df4)
ind = np.arange(N)    # the x locations for the groups

# %%
df10 =  df2[df2['type'] == '汽車竊盜']
df11 =  df10['location'].value_counts().plot.bar()

# %%
df20 = df2[df2['type'] == '自行車竊盜']
df21 = df20['location'].value_counts().plot.bar()

# %%
df30 =  df2[df2['type'] == '機車竊盜']
df31 =  df30['location'].value_counts()

# %%
plt.bar(df4[0], df4[1])

# %%
p1 = plt.bar(ind, df4)
plt.xticks(ind, df4.index)
